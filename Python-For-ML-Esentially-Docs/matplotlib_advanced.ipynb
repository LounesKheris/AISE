# %% [markdown]
# <a href="https://colab.research.google.com/github/Lounes-Kheris/AISE/blob/main/Python-For-ML-Esentially-Docs/matplotlib_advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#methode pyplot

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12, 8))#dimensions, 
x = np.linspace(0, 50, 2000)
plt.subplot(2, 1, 1)
plt.plot(x,np.cos(x))
plt.plot(x, x)
plt.subplot(2, 1, 2)
plt.plot(x, x**2, c='red', label='quadratique')
plt.plot(x, np.sin(x), label='sinus x')
plt.show()
plt.savefig('figure.png')

# %%
# methode OOP

fig , ax = plt.subplots(2, 1, sharex=True)
w = np.linspace(0, 50, 2000)
ax[0].plot(w, w**5)
ax[1].plot(w, np.sin(w))
plt.show()

# %%
#list comprehension
list = []
for i in range(10):
  list.append(i**2)

print(list)

list1 = [i**2 for i in range(10)]
print(list1)

#Nested list : une liste qui comprend d'autres lists

list2 = [[i for i in range(3)] for j in range(3)]
print(list2)

#dictionnary comprehension

dict0 = {'0' : 'pierre',
        '1' : 'jean',
        '2' : 'julie',
        '3' : 'sophie'
}
prenoms = ['pierre', 'jean', 'julie', 'sophie']

dico = {k:v for k, v in enumerate(prenoms)}
print(dico)
print(dico.keys())
print(dico.values())

ages = [24, 51, 55, 87, 96]
dico1 =  {prenom:age for prenom, age in zip(prenoms, ages)}
dico1
#with condition
dico2_cond =  {prenom:age for prenom, age in zip(prenoms, ages) if age > 40}
dico2_cond
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]
# {0: 'pierre', 1: 'jean', 2: 'julie', 3: 'sophie'}
# dict_keys([0, 1, 2, 3])
# dict_values(['pierre', 'jean', 'julie', 'sophie'])
# {'jean': 51, 'julie': 55, 'sophie': 87}

# %%
#practice module : 

dataset = {f"experience {i}": np.random.randn(100) for i in range(4)}

for i in range(4):
  
  print(f"experience{i}",dataset[f"experience {i}"])
# Out:
# experience0 [ 1.29245932  1.26326117 -1.84578598 -0.89687028  0.54837683 -0.17716355
#   0.60626425  0.49724838  1.43072863 -0.07921301 -0.9384385  -0.21556132
#  -0.54671896 -0.31046011  1.84673388 -0.31483843 -0.96596981 -1.14798067
#  -1.18111291  0.13512284 -0.43815827 -1.1732899  -1.64359324 -1.15382714
#   0.51204828  1.00412189  0.35691866 -0.25138854  0.85073944  0.03182165
#   0.3095778  -1.56390262  0.00242094  1.78394417  0.22492244  0.14690513
#   0.00619542 -0.236717   -1.99925768  1.57581991 -0.51368088 -0.02454323
#  -0.3783963   1.28527508 -1.9589394  -1.01093767 -0.54895871 -0.39337548
#   0.41502671 -0.38375535 -2.04495713  1.29762421  1.54693734 -0.87475625
#  -0.46014867  0.49942085  0.12208561 -0.64253798 -1.19857975  0.5554747
#  -2.14705435  0.30088782 -0.21473643 -1.35598274 -0.52565013  0.912602
#   0.60397403 -0.49803401  0.41700695  0.41830326 -0.2723269  -0.32895962
#   0.54576418 -0.92742107 -0.63367692  0.16496785 -1.4752108   0.95034372
# ...

# %%
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12,8))
    
    for k, i in zip(data.keys(), range(1,n+1)):
      plt.subplot(n, 1, i)
      plt.plot(data[k])
      plt.title(k)
    plt.show()

# %%
graphique(dataset)
